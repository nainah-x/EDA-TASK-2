# %%
'''import important libaries'''
# Out:
# 'import important libaries'

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# cleaned and filtered dataset on excel before importing to jupyter notebook for further analysis

# %%
# data contained a number of null values

# %%
df = pd.read_excel(r"C:\Users\MR MOHAMMED\Desktop\ECX.xlsx")

# %%
df.head() #inspecting the first five rows
# Out:
#    transaction_id  product_id  customer_id transaction_date online_order  \
# 0               1           2         2950        2/25/2017        False
# 1               2           3         3120        5/21/2017         True
# 2               3          37          402       10/16/2017        False
# 3               4          88         3135        8/31/2017        False
# 4               5          78          787        10/1/2017         True
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
df.tail()
# Out:
#      transaction_id  product_id  customer_id transaction_date online_order  \
# 995             996          60         2572        3/16/2017         True
# 996             997          59          689        9/19/2017        False
# 997             998          11         1041         1/3/2017        False
# 998             999          74         2217       11/18/2017         True
# 999            1000          79         2492       10/15/2017         True
#
#     order_status           brand product_line product_class product_size  \
# 995     Approved  Giant Bicycles     Standard          high        small
# 996     Approved        WeareA2B     Standard        medium        small
# 997     Approved  Giant Bicycles     Standard          high       medium
# 998     Approved        WeareA2B     Standard        medium       medium
# 999     Approved           Solex      Touring        medium        large
#
#      list_price  standard_cost  product_first_sold_date
# ...

# %%
df.describe() #Summary stat
# Out:
#        transaction_id   product_id  customer_id   list_price  standard_cost  \
# count     1000.000000  1000.000000  1000.000000  1000.000000     994.000000
# mean       500.500000    46.344000  1764.871000  1115.671150     548.930161
# std        288.819436    31.182688  1022.584275   570.796375     395.001672
# min          1.000000     0.000000     1.000000    12.010000       7.210000
# 25%        250.750000    17.750000   859.250000   590.260000     215.030000
# 50%        500.500000    45.000000  1746.000000  1163.890000     507.580000
# 75%        750.250000    76.000000  2673.000000  1635.300000     778.690000
# max       1000.000000   100.000000  3499.000000  2091.470000    1759.850000
#
#        product_first_sold_date
# count               994.000000
# mean              38057.137827
# std                2907.709854
# min               33259.000000
# 25%               35470.000000
# 50%               38206.000000
# 75%               40649.000000
# ...

# %%
df.boxplot() #Finding out what point the data is most concentrated
# Out:
# <AxesSubplot:>

# %%
#We found an outlier on standard_cost

# %%
df.hist() #For a clearer visualization of the outlier
# Out:
# array([[<AxesSubplot:title={'center':'transaction_id'}>,
#         <AxesSubplot:title={'center':'product_id'}>,
#         <AxesSubplot:title={'center':'customer_id'}>],
#        [<AxesSubplot:title={'center':'online_order'}>,
#         <AxesSubplot:title={'center':'list_price'}>,
#         <AxesSubplot:title={'center':'standard_cost'}>],
#        [<AxesSubplot:title={'center':'product_first_sold_date'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
df.shape
# Out:
# (1000, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           1000 non-null   int64
#  1   product_id               1000 non-null   int64
#  2   customer_id              1000 non-null   int64
#  3   transaction_date         1000 non-null   object
#  4   online_order             1000 non-null   float64
#  5   order_status             1000 non-null   object
#  6   brand                    994 non-null    object
#  7   product_line             994 non-null    object
#  8   product_class            994 non-null    object
#  9   product_size             994 non-null    object
#  10  list_price               1000 non-null   float64
#  11  standard_cost            994 non-null    float64
#  12  product_first_sold_date  994 non-null    float64
# dtypes: float64(4), int64(3), object(6)
# ...

# %%
#We begin cleaning the dataset

# %%
df.isnull()
# Out:
#      transaction_id  product_id  customer_id  transaction_date  online_order  \
# 0             False       False        False             False         False
# 1             False       False        False             False         False
# 2             False       False        False             False         False
# 3             False       False        False             False         False
# 4             False       False        False             False         False
# ..              ...         ...          ...               ...           ...
# 995           False       False        False             False         False
# 996           False       False        False             False         False
# 997           False       False        False             False         False
# 998           False       False        False             False         False
# 999           False       False        False             False         False
#
# ...

# %%
df.isnull().sum() #Count the number of missing values in each column
# Out:
# transaction_id              0
# product_id                  0
# customer_id                 0
# transaction_date            0
# online_order               17
# order_status                0
# brand                       6
# product_line                6
# product_class               6
# product_size                6
# list_price                  0
# standard_cost               6
# product_first_sold_date     6
# dtype: int64

# %%
# data has some missing values so we visualize these values using matplotlib's heatmap

# %%
sns.heatmap(df.isnull(),cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
# observe that  from 'brand' to 'product_first_sold_date' the missing/null values seem to increase

# %%
#Replacing the missing values
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# transaction_id             0
# product_id                 0
# customer_id                0
# transaction_date           0
# online_order               0
# order_status               0
# brand                      0
# product_line               0
# product_class              0
# product_size               0
# list_price                 0
# standard_cost              0
# product_first_sold_date    0
# dtype: int64

# %%
df = df.drop(columns=['customer_id']) # drop customer id as its not important to this anaysis

# %%
pd.set_option('display.max_columns',None)
df.head()
# Out:
#    transaction_id  product_id transaction_date  online_order order_status  \
# 0               1           2        2/25/2017           0.0     Approved
# 1               2           3        5/21/2017           1.0     Approved
# 2               3          37       10/16/2017           0.0     Approved
# 3               4          88        8/31/2017           0.0     Approved
# 4               5          78        10/1/2017           1.0     Approved
#
#             brand product_line product_class product_size  list_price  \
# 0           Solex     Standard        medium       medium       71.49
# 1   Trek Bicycles     Standard        medium        large     2091.47
# 2      OHM Cycles     Standard           low       medium     1793.43
# 3  Norco Bicycles     Standard        medium       medium     1198.46
# 4  Giant Bicycles     Standard        medium        large     1765.30
#
#    standard_cost  product_first_sold_date
# 0          53.62                  41245.0
# ...

# %%
df.shape
# Out:
# (994, 12)

# %%
#Data visualization

# %%
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
cor = df.corr()
cor
# Out:
#                          transaction_id  product_id  online_order  list_price  \
# transaction_id                 1.000000    0.025238      0.041729   -0.004226
# product_id                     0.025238    1.000000     -0.005891    0.090242
# online_order                   0.041729   -0.005891      1.000000    0.016545
# list_price                    -0.004226    0.090242      0.016545    1.000000
# standard_cost                  0.018911    0.004888     -0.014146    0.534176
# product_first_sold_date       -0.065822   -0.041211      0.019434    0.106429
#
#                          standard_cost  product_first_sold_date
# transaction_id                0.018911                -0.065822
# product_id                    0.004888                -0.041211
# online_order                 -0.014146                 0.019434
# list_price                    0.534176                 0.106429
# standard_cost                 1.000000                 0.035653
# ...

# %%
plt.figure(figsize=(10,6))
ax = sns.heatmap(cor,annot=True)
#Fix the size problem
plt.ylim(9, 0)
# Out:
# (9.0, 0.0)

# %%
df['product_first_sold_date'] = pd.to_datetime(df['product_first_sold_date'])

# %%
df.head()
# Out:
#    transaction_id  product_id transaction_date  online_order order_status  \
# 0               1           2        2/25/2017           0.0     Approved
# 1               2           3        5/21/2017           1.0     Approved
# 2               3          37       10/16/2017           0.0     Approved
# 3               4          88        8/31/2017           0.0     Approved
# 4               5          78        10/1/2017           1.0     Approved
#
#             brand product_line product_class product_size  list_price  \
# 0           Solex     Standard        medium       medium       71.49
# 1   Trek Bicycles     Standard        medium        large     2091.47
# 2      OHM Cycles     Standard           low       medium     1793.43
# 3  Norco Bicycles     Standard        medium       medium     1198.46
# 4  Giant Bicycles     Standard        medium        large     1765.30
#
#    standard_cost       product_first_sold_date
# 0          53.62 1970-01-01 00:00:00.000041245
# ...

# %%
df[df['online_order']==1.0]
# Out:
#      transaction_id  product_id transaction_date  online_order order_status  \
# 1                 2           3        5/21/2017           1.0     Approved
# 4                 5          78        10/1/2017           1.0     Approved
# 5                 6          25         3/8/2017           1.0     Approved
# 6                 7          22        4/21/2017           1.0     Approved
# 9                10          12        8/30/2017           1.0     Approved
# ..              ...         ...              ...           ...          ...
# 991             992           1        5/25/2017           1.0     Approved
# 992             993          15        6/23/2017           1.0     Approved
# 995             996          60        3/16/2017           1.0     Approved
# 998             999          74       11/18/2017           1.0     Approved
# 999            1000          79       10/15/2017           1.0     Approved
#
# ...

# %%
#import 'customer demographic' dataset as it did not get imorted with the original dataset,
#leave out 'customer address as its not very necessary in this analysis

# %%
df=pd.read_excel(r"C:\Users\MR MOHAMMED\Desktop\ECX2.xlsx")

# %%
df.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot     Dearle    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases         DOB               job_title  \
# 0                                   93  10/12/1953     Executive Secretary
# 1                                   81  12/16/1980  Administrative Officer
# 2                                   61   1/20/1954      Recruiting Manager
# 3                                   33   10/3/1961      Recruiting Manager
# 4                                   56   5/13/1977           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  tenure
# 0                Health      Mass Customer                  N      Yes    11.0
# ...

# %%
df.tail()
# Out:
#      customer_id first_name last_name  gender  \
# 995          996       Aura   Bemlott       U
# 996          997     Ambros    Kernes    Male
# 997          998    Petunia    Dufton  Female
# 998          999       Dido   Leyburn  Female
# 999         1000     Paulie  Castelot  Female
#
#      past_3_years_bike_related_purchases         DOB             job_title  \
# 995                                   67         NaN     Assistant Manager
# 996                                   30    7/3/1981               Teacher
# 997                                   66  12/13/1965    Speech Pathologist
# 998                                   12   4/10/1988    Recruiting Manager
# 999                                   44    8/7/1978  Compensation Analyst
#
#     job_industry_category     wealth_segment deceased_indicator owns_car  \
# 995                    IT      Mass Customer                  N      Yes
# 996    Telecommunications      Mass Customer                  N      Yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          1000 non-null   int64
#  1   first_name                           1000 non-null   object
#  2   last_name                            1000 non-null   object
#  3   gender                               1000 non-null   object
#  4   past_3_years_bike_related_purchases  1000 non-null   int64
#  5   DOB                                  977 non-null    object
#  6   job_title                            1000 non-null   object
#  7   job_industry_category                852 non-null    object
#  8   wealth_segment                       1000 non-null   object
#  9   deceased_indicator                   1000 non-null   object
#  10  owns_car                             1000 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                                0
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     23
# job_title                                0
# job_industry_category                  148
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                  23
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# customer_id                            0
# first_name                             0
# last_name                              0
# gender                                 0
# past_3_years_bike_related_purchases    0
# DOB                                    0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# deceased_indicator                     0
# owns_car                               0
# tenure                                 0
# dtype: int64

# %%
df.shape
# Out:
# (829, 12)

# %%
# drop colums that are not needed
df = df.drop(columns=['customer_id','owns_car','DOB'])

# %%
df.head()
# Out:
#   first_name  last_name gender  past_3_years_bike_related_purchases  \
# 0    Laraine  Medendorp      F                                   93
# 1        Eli    Bockman   Male                                   81
# 2      Arlin     Dearle   Male                                   61
# 3     Talbot     Dearle   Male                                   33
# 5       Curr  Duckhouse   Male                                   35
#
#                 job_title job_industry_category  wealth_segment  \
# 0     Executive Secretary                Health   Mass Customer
# 1  Administrative Officer    Financial Services   Mass Customer
# 2      Recruiting Manager              Property   Mass Customer
# 3      Recruiting Manager                    IT   Mass Customer
# 5           Senior Editor                Retail  High Net Worth
#
#   deceased_indicator  tenure
# 0                  N    11.0
# 1                  N    16.0
# 2                  N    15.0
# 3                  N     7.0
# ...

# %%
# drop customers who are deceased
# drop after gettinf the index
deceased = df[df['deceased_indicator']=='Y'].index
deceased
# Out:
# Int64Index([752], dtype='int64')

# %%
df.drop(deceased,inplace=True)

# %%
# check result
df[df['deceased_indicator']=='Y']
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, gender, past_3_years_bike_related_purchases, job_title, job_industry_category, wealth_segment, deceased_indicator, tenure]
# Index: []

# %%
df.shape
# Out:
# (828, 9)

# %%
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
plt.figure(figsize=(10,6))
ax = sns.heatmap(cor,annot=True)
#Fix the size problem
plt.ylim(10, 0)
# Out:
# (10.0, 0.0)

# %%
# End of analysis
